# %% [markdown]
# Imports

# %%
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

import pandas as pd
import os

# %% [markdown]
# Load the Dataset from kaggle

# %%
# Set the path to the file you'd like to load
file_path = "news_article_dataset.tsv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "articoder/news-dataset-for-news-bias-analysis",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# C:\Users\alsei\AppData\Local\Temp\ipykernel_15548\1091829405.py:5: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df = kagglehub.load_dataset(
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.10), please consider upgrading to the latest version (0.3.12).
# First 5 records:    Unnamed: 0  Title of Headline Roundup description       Topics        Date  \
# 0        3513           Romney in London         NaN    Elections  2012-07-26
# 1        3512     Romney's Overseas Trip         NaN    Elections  2012-08-01
# 2        3511  Biden Comment Controversy         NaN    Elections  2012-08-16
# 3        3510               Romney Taxes         NaN    Elections  2012-08-17
# 4        3509  Skinnydipping Congressman         NaN  US Congress  2012-08-20
#
#                           url_story  \
# 0              /story/romney-london
# 1      /story/romneys-overseas-trip
# 2  /story/biden-comment-controversy
# 3               /story/romney-taxes
# 4  /story/skinnydipping-congressman
#
#                                     left_story_title  \
# 0                      Romney's Olympics false start
# 1  Was Romney's trip 'a great success' or gaffe-f...
# 2            Mission Impossible: Managing Joe Biden
# 3  Obama Campaign Wants Romney To Release 5 Years...
# 4  Exclusive: FBI probed GOP trip with drinking, ...
#
#                                   center_story_title  \
# 0              Shaky Start for Romney Overseas Trip
# 1    Romney's Overseas Trip Produces Hits and Misses
# 2  Campaign Trail: Biden's Comment About 'Chains'...
# 3  Romney Says He Paid A Tax Rate Of At Least 13 ...
# 4  Congressman Who Took Nude Dip In Sea Of Galile...
#
#                                    right_story_title  \
# 0  Romney causes London stir over Olympic readine...
# 1                  RomneyÃ¢â‚¬â„¢s trip a bumpy ride
# 2  Ryan takes on Obama campaign over Biden 'chain...
# 3  Romney campaign doesn't bite on Obama tax retu...
# 4  Account of overseas skinny-dipping fuels clari...
#
#                                      right_story_url  \
# 0  http://politics.blogs.foxnews.com/2012/07/26/r...
# 1  http://www.washingtontimes.com/news/2012/jul/3...
# 2  http://www.foxnews.com/politics/2012/08/15/oba...
# 3  http://www.foxnews.com/politics/2012/08/17/oba...
# 4  http://www.foxnews.com/politics/2012/08/20/rep...
#
#                                     right_story_text  \
# 0  The Brits, taking a break from beating up on t...
# 1  Under mounting pressure to be more open on for...
# 2  Paul Ryan is taking on the Obama campaign dire...
# 3  The Obama campaign made an unusual offer to Mi...
# 4  A bizarre report about Republican congressmen ...
#
#                                     center_story_url  \
# 0  http://online.wsj.com/article/SB10000872396390...
# 1  http://online.wsj.com/article/SB10000872396390...
# 2  http://www.npr.org/blogs/thetwo-way/2012/08/15...
# 3  http://www.npr.org/blogs/itsallpolitics/2012/0...
# 4  http://www.npr.org/blogs/thetwo-way/2012/08/20...
#
#                                    center_story_text  \
# 0  Mitt Romney launched an overseas tour Thursday...
# 1  WARSAWâ€”With a speech lauding Poland as a "de...
# 2  By telling a racially mixed audience in Virgin...
# 3  Republican presidential candidate Mitt Romney ...
# 4  Saying he apologizes for "any embarrassment I ...
#
#                                       left_story_url  \
# 0  http://politicalticker.blogs.cnn.com/2012/07/2...
# 1  http://www.cnn.com/2012/07/31/politics/romney-...
# 2  http://www.politico.com/news/stories/0812/7977...
# 3  http://www.huffingtonpost.com/2012/08/17/obama...
# 4  http://www.politico.com/news/stories/0812/7986...
#
#                                      left_story_text
# 0  Mitt Romney told British leaders he hopes to t...
# 1  OPINION\nWarsaw (CNN) -- In the estimation of ...
# 2  The most emotionally powerful minute of Joe Bi...
# 3  With the spotlight back on Mitt Romney's tax r...
# 4  The FBI probed a late-night swim in the Sea of...

# %% [markdown]
# Have a first look at the columns and null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8478 entries, 0 to 8477
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 8478 non-null   int64
#  1   Title of Headline Roundup  8478 non-null   object
#  2   description                4963 non-null   object
#  3   Topics                     8478 non-null   object
#  4   Date                       8478 non-null   object
#  5   url_story                  8478 non-null   object
#  6   left_story_title           8436 non-null   object
#  7   center_story_title         7706 non-null   object
#  8   right_story_title          8381 non-null   object
#  9   right_story_url            8381 non-null   object
#  10  right_story_text           8375 non-null   object
#  11  center_story_url           7706 non-null   object
#  12  center_story_text          7700 non-null   object
#  13  left_story_url             8436 non-null   object
#  14  left_story_text            8430 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 993.6+ KB

# %% [markdown]
# Restructure the dataframe:
#
# The original dataset contains one row per news roundup, with separate columns for the left, center, and right article titles and texts.
#
# To prepare the data for classification, we transform it into a long-form format where each row represents a single article with an associated political bias label.

# %%
# Rename relevant columns for consistency
df = df.rename(columns={
    'Title of Headline Roundup': 'roundup_title',
    'Topics': 'topics',
    'left_story_title': 'left_title',
    'left_story_text': 'left_text',
    'center_story_title': 'center_title',
    'center_story_text': 'center_text',
    'right_story_title': 'right_title',
    'right_story_text': 'right_text'
})

# Create Left Bias Subset
left_df = df[['roundup_title', 'topics', 'left_title', 'left_text']].dropna(subset=['left_title', 'left_text']).copy()
left_df['bias_label'] = 'left'
left_df.columns = ['roundup_title', 'topics', 'story_title', 'story_text', 'bias_label']

# Create Center Bias Subset
center_df = df[['roundup_title', 'topics', 'center_title', 'center_text']].dropna(subset=['center_title', 'center_text']).copy()
center_df['bias_label'] = 'center'
center_df.columns = ['roundup_title', 'topics', 'story_title', 'story_text', 'bias_label']

# Create Right Bias Subset
right_df = df[['roundup_title', 'topics', 'right_title', 'right_text']].dropna(subset=['right_title', 'right_text']).copy()
right_df['bias_label'] = 'right'
right_df.columns = ['roundup_title', 'topics', 'story_title', 'story_text', 'bias_label']

# Concatenate all subsets
restructured_df = pd.concat([left_df, center_df, right_df], ignore_index=True)

#Sort by roundup title
restructured_df = restructured_df.sort_values(by='roundup_title').reset_index(drop=True)

restructured_df.head(10)
# Out:
#                            roundup_title        topics  \
# 0                 "Dream" 50 Years Later  Civil Rights
# 1                 "Dream" 50 Years Later  Civil Rights
# 2                 "Dream" 50 Years Later  Civil Rights
# 3          "Good Shutdown" in September?      Politics
# 4          "Good Shutdown" in September?      Politics
# 5          "Good Shutdown" in September?      Politics
# 6          "Skinny Repeal" Motions Fails     US Senate
# 7          "Skinny Repeal" Motions Fails     US Senate
# 8          "Skinny Repeal" Motions Fails     US Senate
# 9  "Trump University" Documents Unsealed     Elections
#
#                                          story_title  \
# 0  Thousands Gather In D.C. To Mark 1963 Civil Ri...
# 1  March In Washington To Continue Focus On Civil...
# 2                     Remembering My Uncle's 'Dream'
# 3  President Trump Calls for a "Good Shutdown" in...
# 4                  Trump: US ‘needs a good shutdown’
# 5  Trump's frustration with budget compromise has...
# 6  Obamacare repeal is dead for now. What could t...
# 7   Why Senate Republicans couldn’t repeal Obamacare
# 8  Senate Fails To Pass Motion To Proceed On ‘Ski...
# 9  Trump University ‘Playbooks’ Unsealed in Lawsu...
#
#                                           story_text bias_label
# 0  People are assembling on the National Mall to ...     center
# 1  Alice Long planned months ago to use vacation ...       left
# 2  Fifty years ago, a valiant group of people fro...      right
# 3  President Donald Trump made a bold statement o...      right
# 4  President Trump on Tuesday called for a "good ...     center
# 5  Congress looks set to enact a bipartisan spend...       left
# 6  The Senate’s effort to repeal and replace Obam...     center
# 7  In a stunning turn, Senate Republicans — in th...       left
# 8  Senate Majority Leader Mitch McConnell failed ...      right
# 9  Trump University gave employees detailed instr...      right

# %%
# Create the folder if it doesn't exist
os.makedirs("data", exist_ok=True)

# Now save the file
restructured_df.to_csv("data/restructured.csv", index=False)
