# %%
import requests
import pandas as pd

url = "https://seo-keyword-research.p.rapidapi.com/keynew.php"

querystring = {"keyword":"handball","country":"us"}

headers = {
	"x-rapidapi-key": "8284353d4cmshcb6ef32868588cbp1d4d9ejsn4a02829cf3b6",
	"x-rapidapi-host": "seo-keyword-research.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

if response.status_code == 200:
    data = response.json()
    
    # Convert to DataFrame
    df = pd.DataFrame(data)
    
    # Display table
    from IPython.display import display
   

    # Optional: sort by search volume
    df_sorted = df.sort_values(by="vol", ascending=False)
    display(df_sorted)

else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
#                             text   cpc     vol       v competition   score
# 1                 spezial adidas  0.48  201000  201000         low  0.1200
# 2        adidas handball spezial  0.72   90500   90500         low  0.1800
# 3       adidas handball spezials  0.63   90500   90500         low  0.1575
# 5              handball handball  0.92   74000   74000         low  0.2300
# 0                       handball  0.92   74000   74000         low  0.2300
# ..                           ...   ...     ...     ...         ...     ...
# 87         handball shoes mizuno  0.28      40      40         low  0.0700
# 88           handball court wall  0.00      30      30         low  0.0000
# 89  handball spezial sneaker men  1.16      20      20         low  0.2900
# 90                   wc handball  0.00      10      10         low  0.0000
# 91                   handball wc  0.00      10      10         low  0.0000
#
# [92 rows x 6 columns]
